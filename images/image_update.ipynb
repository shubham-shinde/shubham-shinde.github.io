# %%
from PIL import Image

# %%
img = Image.open('home-img3.jpg')

# %%
w, h = img.size

# %%
cropped_img = img.crop(box=(0, 0, w, h-180))
cropped_img
# Out:
# <PIL.Image.Image image mode=RGB size=768x844>

# %%
cropped_img.save('home-img5.jpg')
